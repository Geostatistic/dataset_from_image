# %% [markdown]
# ## Importando os pacotes necessários

# %%
import pygeostat as gs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importando o banco de dados

# %%
walker_lake = gs.DataFile(flname='dados/WalkerLake_01/walker_sample_gslib.txt', dh='I', x='X', y='Y')

# %% [markdown]
# Os bancos de dados importados com a classe DataFile são um data frame pandas chamado data por padrão, então todas as funções e métodos do pandas funcionam aqui

# %%
print('Primeiras 5 linhas do data frame: \n', walker_lake.data.head())
# Out:
# Primeiras 5 linhas do data frame:
#       I     X     Y      V   U    T
# 0  1.0  11.0   8.0    0.0 NaN  2.0
# 1  2.0   8.0  30.0    0.0 NaN  2.0
# 2  3.0   9.0  48.0  224.4 NaN  2.0
# 3  4.0   8.0  69.0  434.4 NaN  2.0
# 4  5.0   9.0  90.0  412.1 NaN  2.0

# %%
print('Primeiras 5 linhas da variável V: \n', walker_lake.data['V'].head())
# Out:
# Primeiras 5 linhas da variável V:
#  0      0.0
# 1      0.0
# 2    224.4
# 3    434.4
# 4    412.1
# Name: V, dtype: float64

# %%
#filtrando variável V > 500
filtro = walker_lake.data['V'] > 500

#aplicando o filtro
print('Primeiras 5 linhas do data frame filtrado: \n', walker_lake.data[filtro].head())
# Out:
# Primeiras 5 linhas do data frame filtrado:
#         I     X      Y      V   U    T
# 5    6.0  10.0  110.0  587.2 NaN  2.0
# 18  19.0  31.0   68.0  895.2 NaN  2.0
# 19  20.0  28.0   88.0  702.6 NaN  2.0
# 30  31.0  49.0   11.0  653.3 NaN  2.0
# 34  35.0  50.0   88.0  820.8 NaN  2.0

# %%
#é fácil criar uma coluna a partir de uma operação, V*3.5 por exemplo
walker_lake.data['V*3.5'] = walker_lake.data['V']*3.5

print(walker_lake.head())
# Out:
#      I     X     Y      V   U    T    V*3.5
# 0  1.0  11.0   8.0    0.0 NaN  2.0     0.00
# 1  2.0   8.0  30.0    0.0 NaN  2.0     0.00
# 2  3.0   9.0  48.0  224.4 NaN  2.0   785.40
# 3  4.0   8.0  69.0  434.4 NaN  2.0  1520.40
# 4  5.0   9.0  90.0  412.1 NaN  2.0  1442.35

# %%
#as estatísticas básicas são mostradas com o comando describe
print(walker_lake.data.describe(include='all'))

#para duas variáveis específicas
print(walker_lake.data[['V','U']].describe())
# Out:
#                 I           X           Y            V            U  \
# count  470.000000  470.000000  470.000000   470.000000   275.000000
# mean   235.500000  111.089362  141.221277   435.298723   604.081091
# std    135.821574   70.894682   77.968954   299.882302   767.405620
# min      1.000000    8.000000    8.000000     0.000000     0.000000
# 25%    118.250000   51.000000   80.000000   184.600000    82.150000
# 50%    235.500000   89.000000  139.500000   424.000000   319.300000
# 75%    352.750000  170.000000  208.000000   640.850000   844.550000
# max    470.000000  251.000000  291.000000  1528.100000  5190.100000
#
#                 T        V*3.5
# count  470.000000   470.000000
# mean     1.904255  1523.545532
# std      0.294554  1049.588057
# min      1.000000     0.000000
# 25%      2.000000   646.100000
# 50%      2.000000  1484.000000
# 75%      2.000000  2242.975000
# max      2.000000  5348.350000
#                  V            U
# count   470.000000   275.000000
# mean    435.298723   604.081091
# std     299.882302   767.405620
# min       0.000000     0.000000
# 25%     184.600000    82.150000
# 50%     424.000000   319.300000
# 75%     640.850000   844.550000
# max    1528.100000  5190.100000

# %%
#assim como a matriz de correlação
print(walker_lake.data[['V','U','V*3.5']].corr())
# Out:
#               V         U     V*3.5
# V      1.000000  0.551482  1.000000
# U      0.551482  1.000000  0.551482
# V*3.5  1.000000  0.551482  1.000000

# %% [markdown]
# Da mesma forma que foram importados os bancos de dados podem ser exportados como gslib, vtk, csv, xls ou hdf5

# %%
walker_lake.writefile(flname='arquivos  exportados/walker_modificado.dat', fltype='gslib')

# %% [markdown]
# ## Análise exploratória dos dados

# %% [markdown]
# Plotando mapas

# %%
gs.locmap(walker_lake, var = "V", title='Mapa da variável V', outfl='figuras/mapav', figsize=(7,7))
gs.locmap(walker_lake, var = "U", title='Mapa da variável U', outfl='figuras/mapau', figsize=(7,7))
gs.locmap(walker_lake, var = "T", title='Mapa da variável T', outfl='figuras/mapat', figsize=(7,7))

# %% [markdown]
# Obtendo os pesos de desagrupamento

# %% [markdown]
# Com o pygeostat é possível rodar programas da biblioteca GSLib

# %%
#para rodar programas GSLib definimos uma variável do tip string que contem o arquivo de parâmetros da rotina 
celldecluspar = '''                   Parameters for CELLDECLUS
                  *************************

START OF PARAMETERS:
{datafl}                    -file with data
{varcols}                   -columns for X, Y, Z, and variable
-1.0e21     1.0e21          -trimming limits
{sumoutfl}                  -file for summary output
{dataoutfl}                 -file for output with data and weights
{anis}                      -Y and Z cell anisotropy (Ysize=size*Yanis)
{cellspar}                  -number of cell sizes, min size, max size
-1  6.0                     -cell size to keep: -1 = minimum
                                                 0 = specified
                                                +1 = maximum

'''

#precisamos também definir um dicionário que substituirá os parâmetros no arquivo .par
celldecluspars = {
'datafl':walker_lake.flname,
'varcols':'2 3 0 4',
'sumoutfl':'01 declus/sumoutfl.out',
'dataoutfl':'01 declus/dataoutfl.out',
'anis':'1 1',
'cellspar':'15 1 50'
}

#precisamos informar qual o executável e arquivo de paramêtro queremos rodar
celldeclus = gs.Program(program='01 declus/celldeclus/CellDeclus', parfile='01 declus/celldeclus/histplt.par')

#finalmente podemos rodar o programa
celldeclus.run(parstr=celldecluspar.format(**celldecluspars))
# Out:
# Calling:  ['01 declus/celldeclus/CellDeclus', '01 declus/celldeclus/histplt.par']
#
#  CELLDECLUS Version: 4.000
#
#   data file = dados/WalkerLake_01/walker_sample_gslib.
#   columns =            2           3           0           4
#   tmin,tmax =  -1.0000000E+21  1.0000000E+21
#   summary file = 01 declus/sumoutfl.out
#   output file = 01 declus/dataoutfl.out
#   anisotropy =    1.000000       1.000000
#   ncell min max =           15   1.000000       50.00000
#   minmax flag =           -1   6.000000
#
#
#  There are      470 data with:
#    mean value            =   435.29858
#    minimum and maximum   =   0.0000000      1528.1000
#    size of data vol in X =   243.00000
#    size of data vol in Y =   283.00000
#    size of data vol in Z =   0.0000000
#
#    declustered mean      =   291.71292
#    min and max weight    =  0.29578915      2.6123421
#    equal weighting       =   1.0000000
#
#
#  CELLDECLUS Version: 4.000 Finished

# %%
#vamos checar os resultados do celldeclus
declus_wt = gs.DataFile(flname='01 declus/sumoutfl.out')

#escolhendo quem serão os eixos do scatterplot
x, y = declus_wt.data['Cell Size'], declus_wt.data['Declustered Mean']

#plotando o scatterplot
gs.scatplt(x,y, c='k', figsize=(7,7), title='Dimensão da célula vs. média desagrupada')

# %%
#e agora importar a dataset com pesos de desagrupamento
walker_lake_declus = gs.DataFile(flname='01 declus/dataoutfl.out', dh='I', x='X', y='Y')

print(walker_lake_declus.data.head())
# Out:
#      I     X     Y      V   U    T  Cell Declustering Weight
# 0  1.0  11.0   8.0    0.0 NaN  2.0                  2.577234
# 1  2.0   8.0  30.0    0.0 NaN  2.0                  2.503010
# 2  3.0   9.0  48.0  224.4 NaN  2.0                  2.005195
# 3  4.0   8.0  69.0  434.4 NaN  2.0                  1.493753
# 4  5.0   9.0  90.0  412.1 NaN  2.0                  1.208923

# %% [markdown]
# Plotando histogramas desagrupados

# %%
gs.histplt(walker_lake_declus, var='V', wt='Cell Declustering Weight', figsize=(7,5), outfl='figuras/pdfv', title='PDF desagrupado da variável V')

gs.histplt(walker_lake_declus, var='V', wt='Cell Declustering Weight', icdf=True, figsize=(7,5), outfl='figuras/cdfv', title='CDF desagrupado da variável V')

# %% [markdown]
# Plotando um scatterplot entre as variáveis V e U

# %%
#definindo x e y
x, y = walker_lake_declus.data['V'], walker_lake_declus.data['U']

#plotando o scatterplot
gs.scatplt(x,y, figsize=(7,7), title='Scatterplot U vs. V', stat_blk='all')

# %% [markdown]
# Variografia

# %% [markdown]
# Rodando o varmap

# %%
varmappar = '''                  Parameters for VARMAP
                  *********************

START OF PARAMETERS:
{datafl}                -file with data
1   {var}               -number of variables: column numbers
-1.0e21     1.0e21      -trimming limits
0                       -1=regular grid, 0=scattered values
20   20    1            -if =1: nx,     ny,   nz
5.0  5.0  1.0           -xsiz, ysiz, zsiz
{coords} 0              -if =0: columns for x,y, z coordinates
{outfl}                 -file for variogram output
{nlags}                 -nxlag, nylag, nzlag
{dlags}                 -dxlag, dylag, dzlag
5                       -minimum number of pairs
1                       -standardize sill? (0=no, 1=yes)
1                       -number of variograms
1   1   1               -tail, head, variogram type


type 1 = traditional semivariogram
     2 = traditional cross semivariogram
     3 = covariance
     4 = correlogram
     5 = general relative semivariogram
     6 = pairwise relative semivariogram
     7 = semivariogram of logarithms
     8 = semimadogram
     9 = indicator semivariogram - continuous
     10= indicator semivariogram - categorical

'''

varmappars = {
'datafl':walker_lake_declus.flname,
'var':walker_lake_declus.gscol('V'),
'coords':walker_lake_declus.gscol(['X','Y']),
'outfl':'02 varmap/varmapout.out',
'nlags':'20 20 0',
'dlags':'6 6 6'
}

varmap = gs.Program(program='02 varmap/varmap_3000/varmap', parfile='02 varmap/varmap_3000/varmap.par')

varmap.run(parstr=varmappar.format(**varmappars))
# Out:
# Calling:  ['02 varmap/varmap_3000/varmap', '02 varmap/varmap_3000/varmap.par']
#
#  VARMAP Version: 3.000
#
#   data file = 01 declus/dataoutfl.out
#   number of variables =            1
#   columns =            4
#   trimming limits =  -1.0000000E+21  1.0000000E+21
#   working with scattered data
#   nx,ny,nz =           20          20           1
#   xsiz,ysiz,zsiz =    5.000000       5.000000       1.000000
#   columns for x, y, and z =            2           3           0
#   output file = 02 varmap/varmapout.out
#   nxlag,nylag,nzlag =           20          20           0
#   dxlag,dylag,dzlag =    6.000000       6.000000       6.000000
#   minimum number of pairs =            5
#   flag to standardize sills =            1
#   number of variograms =            1
#   tail,head,type =            1           1           1
#
#  Variable number            1
#    Number   =          470
#    Average  =    435.2987
#    Variance =    89738.05
#
#  Variogram  1 Semivariogram          :  tail=V            head=V
#
#  VARMAP Version: 3.000 Finished

# %%
#um script simples para ler a definição do grid a partir do arquivo de saída do varmap
fp = open('02 varmap/varmapout.out', 'r')

for x, line in enumerate(fp):
    if x ==1:
        griddefstr = line.split()
        break

fp.close

print(griddefstr)
# Out:
# ['6', '41', '41', '1', '-20.000000', '-20.000000', '0.0000000', '1.00000', '1.00000', '1.00000', '1']

# %%
#importando os resultados do varmap
varmapgrid = gs.GridDef([griddefstr[1], griddefstr[4], griddefstr[7], griddefstr[2], griddefstr[5], griddefstr[8], griddefstr[3], griddefstr[6], griddefstr[9]])
varmapout = gs.DataFile(flname='02 varmap/varmapout.out', griddef=varmapgrid)

print(varmapout.data.describe())
# Out:
#          variogram  number of pairs    head mean    tail mean  head variance  \
# count  1679.000000      1681.000000  1679.000000  1679.000000         1679.0
# mean      1.052390        69.781083   441.709595   441.709590            0.0
# std       0.264612        46.823246    92.764043    92.764042            0.0
# min       0.011420         4.000000   139.354550   139.354550            0.0
# 25%       0.878490        34.000000   371.105640   371.105655            0.0
# 50%       1.030760        57.000000   446.539980   446.539980            0.0
# 75%       1.213690        93.000000   511.067110   511.067065            0.0
# max       2.216410       502.000000   739.316650   739.316830            0.0
#
#        tail variance
# count         1679.0
# mean             0.0
# std              0.0
# min              0.0
# 25%              0.0
# 50%              0.0
# 75%              0.0
# max              0.0

# %%
#plotando os resultados 
gs.pixelplt(varmapout, var='variogram', title='Varmap da variável V', figsize=(7,7), outfl='figuras/varmap')

#uma outra forma de visualizar os resultados
gs.contourplt(varmapout, figsize=(7,7), outfl='figuras/countourmap', title='Contorno do varmap da variável V')

# %% [markdown]
# A variografia no pygeostat é centrada na classe gs.Variogram

# %%
#vamos definir a variável variograma
varg = gs.Variogram(datafl=walker_lake_declus, var='V', ndim=2, ndir=2, mute=False, omnihz=False, variostd=True)

#vamos definir a direção de maior continuidade encontrada a partir do varmap
varg.inferdirections(azm=167, dip=0, tilt=0)

#vamos definir os parâmetros para o calculo do variograma
varg.settols(nlags=30, lagdist=5, lagtol=2.5, azmtol=22.5)

#finalmente vamos validar os parâmetros de cálculo
varg.validcalcpars()
# Out:
# WARNING: May be unstable, particularly for variograms with dipping         major directions. Please use the CCG programs (varcalc,          varmodel, varsim) in combination with gs.varplt if you          encounter issues
# The major direction has been set to a [azm, dip, tilt] value of: [0, 0.0, 0.0]
# The minor direction has been set to a [azm, dip, tilt] value of: [270, 0.0, 0.0]
# The major direction has been set to a [azm, dip, tilt] value of: [167.0, 0.0,
# 0.0]
# The minor direction has been set to a [azm, dip, tilt] value of: [77.0, 0.0,
# 0.0]
# WARNING: The parameter 'nlags' has a single value which is being repeated for
#          all directions
# WARNING: The parameter 'lagdist' has a single value which is being repeated for
#          all directions
# WARNING: The parameter 'lagtol' has a single value which is being repeated for
#          all directions
# WARNING: The parameter 'azmtol' has a single value which is being repeated for
#          all directions
# WARNING: The parameter 'diptol' has a single value which is being repeated for
#          all directions
# WARNING: The parameter 'bandhorz' has a single value which is being repeated for
#          all directions
# WARNING: The parameter 'bandvert' has a single value which is being repeated for
#          all directions

# %%
#calculando o variograma
varg.varcalc()

# mostrando os parâmetros utilizados ns calculos
print('\nParâmetros utilizados nos cálculos:')
for key, val in varg.calcpars.items():
    print(key+' = ', val)
    
#mostrando as primeiras linhas da tabela de resultados
print('\n Variograma experimemntal:\n', varg.expvargs[0].head(20))
# Out:
# Parâmetros utilizados nos cálculos:
# variotypes =  1
# variotails =  V
# varioheads =  V
# azm =  [167.0, 77.0]
# dip =  [0.0, 0.0]
# tilt =  [0.0, 0.0]
# azmtol =  [22.5, 22.5]
# diptol =  [90, 90]
# nlags =  [30, 30]
# lagdist =  [5, 5]
# lagtol =  [2.5, 2.5]
# bandhorz =  [1e+21, 1e+21]
# bandvert =  [1e+21, 1e+21]
# variostd =  True
# variosills =  None
# strict =  True
# variocutcat =  None
# ang1 =  167.0
# ang2 =  0.0
# ang3 =  0.0
#
#  Variograma experimemntal:
#              h     vario  numpairs  azimuth  dip
# 0    2.000000  0.000064         2    167.0  0.0
# 1    6.875901  0.463952        32    167.0  0.0
# 2   10.409509  0.500804       662    167.0  0.0
# 3   14.289497  0.617620       200    167.0  0.0
# 4   20.337620  0.603672      1129    167.0  0.0
# 5   24.246412  0.727569       436    167.0  0.0
# 6   30.428273  0.787067      1006    167.0  0.0
# 7   34.667130  0.913477       652    167.0  0.0
# 8   40.249432  0.857402      1369    167.0  0.0
# 9   44.746392  0.839642       969    167.0  0.0
# 10  50.230621  0.968465      1502    167.0  0.0
# 11  54.863735  0.898311       960    167.0  0.0
# 12  60.285818  0.974660      2117    167.0  0.0
# 13  64.653177  1.049399      1185    167.0  0.0
# 14  70.292221  1.071826      2177    167.0  0.0
# 15  74.582342  0.866257      1290    167.0  0.0
# 16  80.216688  0.992218      2341    167.0  0.0
# 17  84.686687  0.957862      1381    167.0  0.0
# 18  90.213094  1.037176      2168    167.0  0.0
# 19  94.687964  1.042902      1234    167.0  0.0

# %%
fig = varg.plot(titles='Variograma experimental da variável V', separate_plts=False, figsize=(7,5), ms=7, outfl='figuras/variograma_exp_V')
#o comando fig= evita que duas imagens sejam plotadas

# %% [markdown]
# Modelando o variograma

# %%
#modelando o variograma com o varfit
varg.fitmodel(nst=2, sill=1, maxiter=2500)

#mostrando o modelo
print('\n Variograma variável V: {}\n'.format(varg.model))
# Out:
#  Variograma variável V: 2    0.173851442              -  nst, nugget effect
# 1    0.673291974   167.0   0.0   0.0   - it,cc,ang1,ang2,ang3
#        63.83045779510734    24.934210882384832    75.09400397590599       - a_hmax, a_hmin, a_vert
# 1    0.152856584   167.0   0.0   0.0   - it,cc,ang1,ang2,ang3
#        5.53085762130618    8.01311347053883    150.18800795181198       - a_hmax, a_hmin, a_vert

# %%
#plotando o modelo
fig = varg.plot(titles='Variograma experimental + modelo da variável V', separate_plts=False, model=True, figsize=(7,5), ms=7, outfl='figuras/variograma_model_V')

# %% [markdown]
# ## Estimativas

# %% [markdown]
# Antes de qualquer coisa vamos validar o modelo de variograma e estratégia de busca de krigagem via validação cruzada

# %%
kt3dpar = '''                  Parameters for KT3D
                  *******************

START OF PARAMETERS:
{flname}              -file with data
1  2  3  0  4  0      -columns for DH,X,Y,Z,var,sec var
-1.0e21   1.0e21      -trimming limits
1                     -option: 0=grid, 1=cross, 2=jackknife
{flname}              -file with jackknife data
2   3   0    4    0   -columns for X,Y,Z,vr and sec var
3                     -debugging level: 0,1,2,3
03 OK/kt3d.dbg        -file for debugging output
{outfl}               -file for kriged output
50   0.5    1.0       -nx,xmn,xsiz
50   0.5    1.0       -ny,ymn,ysiz
1    0.5    1.0       -nz,zmn,zsiz
1    1      1         -x,y and z block discretization
{minmax}              -min, max data for kriging
{maxoct}              -max per octant (0-> not used)
{srchradi}            -maximum search radii
{angs}                -angles for search ellipsoid
1     2.302           -0=SK,1=OK,2=non-st SK,3=exdrift
0 0 0 0 0 0 0 0 0     -drift: x,y,z,xx,yy,zz,xy,xz,zy
0                     -0, variable; 1, estimate trend
extdrift.dat          -gridded file with drift/mean
4                     -column number in gridded file
{varg}
'''

kt3dpars = {
'flname':walker_lake_declus.flname,
'outfl':'03 OK/xvalid.out',
'minmax':'3 24',
'maxoct':'3',
'srchradi':'150 63 0',
'angs':'167 0 0',
'varg':varg.model
}

kt3d = gs.Program(program= '03 OK/kt3d_3000/kt3d', parfile='03 OK/kt3d_3000/kt3d.par')

kt3d.run(parstr=kt3dpar.format(**kt3dpars))
# Out:
# Calling:  ['03 OK/kt3d_3000/kt3d', '03 OK/kt3d_3000/kt3d.par']
#
#  KT3D Version: 3.000
#
#   data file = 01 declus/dataoutfl.out
#   columns =            1           2           3           0           4
#            0
#   trimming limits =  -1.0000000E+21  1.0000000E+21
#   kriging option =            1
#   jackknife data file = 01 declus/dataoutfl.out
#   columns =            2           3           0           4           0
#   debugging level =            3
#   debugging file = 03 OK/kt3d.dbg
#   output file = 03 OK/xvalid.out
#   nx, xmn, xsiz =           50  0.5000000       1.000000
#   ny, ymn, ysiz =           50  0.5000000       1.000000
#   nz, zmn, zsiz =            1  0.5000000       1.000000
#   block discretization:           1           1           1
#   ndmin,ndmax =            3          24
#   max per octant =            3
#   search radii =    150.0000       63.00000      0.0000000E+00
#   search anisotropy angles =    167.0000      0.0000000E+00  0.0000000E+00
#   ktype, skmean =           1   2.302000
#   drift terms =            0           0           0           0           0
#            0           0           0           0
#   itrend =            0
#   external drift file = extdrift.dat
#   variable in external drift file =            4
#   nst, c0 =            2  0.1738514
#   it,cc,ang[1,2,3];            1  0.6732920       167.0000      0.0000000E+00
#   0.0000000E+00
#   a1 a2 a3:    63.83046       24.93421       75.09400
#   it,cc,ang[1,2,3];            1  0.1528566       167.0000      0.0000000E+00
#   0.0000000E+00
#   a1 a2 a3:    5.530858       8.013113       150.1880
#  Data for KT3D: Variable number            4
#    Number   =          470
#    Average  =    435.2986
#    Variance =    89738.14
#  Setting up rotation matrices for variogram and search
#  Setting up super block search strategy
#
#  Working on the kriging
#    currently on estimate        47
#    currently on estimate        94
#    currently on estimate       141
#    currently on estimate       188
#    currently on estimate       235
#    currently on estimate       282
#    currently on estimate       329
#    currently on estimate       376
#    currently on estimate       423
#    currently on estimate       470
#
# Estimated        470 blocks
#   average    442.02975
#   variance   50023.406
#
#
#   mean error 145.40761
#   mean sqd e 33578.688
#
#  KT3D Version: 3.000 Finished

# %%
#importando o arquqivo da validação cruzada
x_valid = gs.DataFile(flname='03 OK/xvalid.out', x='X', y='Y', z='Z')

print(x_valid.data.head())
# Out:
#       X     Y    Z       True   Estimate  EstimationVariance  Error: est-true
# 0  11.0   8.0  0.5    0.00000  120.54652            1.023065       120.546520
# 1   8.0  30.0  0.5    0.00000  141.03615            0.835356       141.036150
# 2   9.0  48.0  0.5  224.39999  223.48273            0.793219        -0.917267
# 3   8.0  69.0  0.5  434.39999  427.50809            0.781252        -6.891907
# 4   9.0  90.0  0.5  412.10001  583.16339            0.698986       171.063390

# %%
#plotando o scatterplot real x estimado
x, y = x_valid.data['Estimate'], x_valid.data['True']

gs.scatxval(x, y, title='Real vs. Estimado', outfl='figuras/real_est', figsize=(7,5))

#plotando o histograma do erro
gs.histplt(x_valid, var='Error: est-true', title='Histograma do erro', outfl='figuras/error_hist', figsize=(7,5))

#plotando scatterplot do erro versus teor real
x1, y1 = x_valid.data['True'], x_valid.data['Error: est-true']

gs.scatplt(x1,y1, c='k', figsize=(7,7), title='Erro vs.teor')

# %% [markdown]
#  Krigagem em um grid

# %%
#vamos primeiro criar um grid
#a funcao infergriddef cria um grid a partir das dimensoes do bloco OU numero de blocos
walker_lake_declus.infergriddef(blksize=(5,5,None), databuffer=2)
# Out:
# Pygeostat GridDef:
# 50 8.5 5.0
# 58 8.5 5.0
# 1 0.5 1.0

# %%
kt3dpar = '''                  Parameters for KT3D
                  *******************

START OF PARAMETERS:
{flname}              -file with data
1  2  3  0  4  0      -columns for DH,X,Y,Z,var,sec var
-1.0e21   1.0e21      -trimming limits
0                     -option: 0=grid, 1=cross, 2=jackknife
{flname}              -file with jackknife data
2   3   0    4    0   -columns for X,Y,Z,vr and sec var
3                     -debugging level: 0,1,2,3
03 OK/kt3d.dbg        -file for debugging output
{outfl}               -file for kriged output
{griddef}
5    5      5         -x,y and z block discretization
{minmax}              -min, max data for kriging
{maxoct}              -max per octant (0-> not used)
{srchradi}            -maximum search radii
{angs}                -angles for search ellipsoid
1     2.302           -0=SK,1=OK,2=non-st SK,3=exdrift
0 0 0 0 0 0 0 0 0     -drift: x,y,z,xx,yy,zz,xy,xz,zy
0                     -0, variable; 1, estimate trend
extdrift.dat          -gridded file with drift/mean
4                     -column number in gridded file
{varg}
'''

kt3dpars = {
'flname':walker_lake_declus.flname,
'outfl':'03 OK/kt3d_OK.out',
'griddef':walker_lake_declus.griddef,
'minmax':'3 24',
'maxoct':'3',
'srchradi':'150 63 0',
'angs':'167 0 0',
'varg':varg.model
}

kt3d = gs.Program(program= '03 OK/kt3d_3000/kt3d', parfile='03 OK/kt3d_3000/kt3d.par')

kt3d.run(parstr=kt3dpar.format(**kt3dpars))
# Out:
# Calling:  ['03 OK/kt3d_3000/kt3d', '03 OK/kt3d_3000/kt3d.par']
#
#  KT3D Version: 3.000
#
#   data file = 01 declus/dataoutfl.out
#   columns =            1           2           3           0           4
#            0
#   trimming limits =  -1.0000000E+21  1.0000000E+21
#   kriging option =            0
#   jackknife data file = 01 declus/dataoutfl.out
#   columns =            2           3           0           4           0
#   debugging level =            3
#   debugging file = 03 OK/kt3d.dbg
#   output file = 03 OK/kt3d_OK.out
#   nx, xmn, xsiz =           50   8.500000       5.000000
#   ny, ymn, ysiz =           58   8.500000       5.000000
#   nz, zmn, zsiz =            1  0.5000000       1.000000
#   block discretization:           5           5           5
#   ndmin,ndmax =            3          24
#   max per octant =            3
#   search radii =    150.0000       63.00000      0.0000000E+00
#   search anisotropy angles =    167.0000      0.0000000E+00  0.0000000E+00
#   ktype, skmean =           1   2.302000
#   drift terms =            0           0           0           0           0
#            0           0           0           0
#   itrend =            0
#   external drift file = extdrift.dat
#   variable in external drift file =            4
#   nst, c0 =            2  0.1738514
#   it,cc,ang[1,2,3];            1  0.6732920       167.0000      0.0000000E+00
#   0.0000000E+00
#   a1 a2 a3:    63.83046       24.93421       75.09400
#   it,cc,ang[1,2,3];            1  0.1528566       167.0000      0.0000000E+00
#   0.0000000E+00
#   a1 a2 a3:    5.530858       8.013113       150.1880
#  Data for KT3D: Variable number            4
#    Number   =          470
#    Average  =    435.2986
#    Variance =    89738.14
#  Setting up rotation matrices for variogram and search
#  Setting up super block search strategy
#
#  Working on the kriging
#    currently on estimate       290
#    currently on estimate       580
#    currently on estimate       870
#    currently on estimate      1160
#    currently on estimate      1450
#    currently on estimate      1740
#    currently on estimate      2030
#    currently on estimate      2320
#    currently on estimate      2610
#    currently on estimate      2900
#
# Estimated       2900 blocks
#   average    292.60062
#   variance   38452.898
#
#
#  KT3D Version: 3.000 Finished

# %%
#importando a krigagem
kt3d_OK = gs.DataFile(flname='03 OK/kt3d_OK.out', griddef=walker_lake_declus.griddef)

print(kt3d_OK.data.head())
# Out:
#     Estimate  EstimationVariance
# 0  62.864159            0.272208
# 1  52.526176            0.258614
# 2  77.926323            0.480568
# 3  88.069267            0.497735
# 4  70.662582            0.318325

# %%
#plotando o mapa
gs.pixelplt(kt3d_OK, var='Estimate', figsize=(7,7), outfl='figuras/OK_V', title='OK Variável V')
gs.pixelplt(kt3d_OK, var='EstimationVariance', figsize=(7,7), outfl='figuras/OK_var_V', title='OK_var Variável V')

#mudando a escala de cores para uma mais familiar
gs.pixelplt(kt3d_OK, var='Estimate', figsize=(7,7), outfl='figuras/OK_V_jet', title='OK Variável V', cmap='jet')

# %%
#plotando o histograma dos blocos krigados
gs.histplt(kt3d_OK, var='Estimate', figsize=(7,5), title='Histograma dos blocos krigados V', outfl='figuras/hist_OK')

# %% [markdown]
# ## Validando o modelo

# %% [markdown]
# Gerando swath plots nas direções x e y

# %%
swathpltpar = '''START OF PARAMETERS:
2                     -number of data files to plot
{pointfl}             -data file
0                     -scattered or gridded? (gridded = 1)
2 3 0 4               -columns for X,Y,Z,Var
0.0001   1.0e21       -trimming limits
2  1  5  1            -line width (0=none), dashing, bullet size (0=none), color
{gridfl}              -data file
1                     -scattered or gridded? (gridded = 1)
1                     -column number
{griddef}
0.0001   1.0e21       -trimming limits
2  0  0  2            -line width (0=none), dashing, bullet size (0=none), color
{outfl}               -file for Postscript output
{dir}                 -azimuth, dip
{bins}                -number of bins
{xminmax}             -X min and max
{yminmax}             -Y min and max, (0=arith, 1=log) (max<min for auto scaling based on data file #1)
0                     -plot histogram of the bin count of the first data file (0=no, 1=yes)
{title}               -title
Distance              -X axis label (default=get from data file #1)
Grade                 -y axis label (default=get from data file #1)
1   25  75            -error bars?(1=yes), lower percentile, upper percentile
'''

swathplt = gs.Program(program='04 swathplots/swathplt1001/swathplt/swathplt', parfile='04 swathplots/swathplt1001/swathplt/swathplt.par')


#agora vamos scriptar rotinas GSLib para rodar em paralelo
#o primeiro passo é criar uma lista vazia onde serão armazenados os dicionários de parâmetros
callpars = []

#agora iniciaremos o loop
for directions in ['0 0', '90 0']:

    #um dicionário para cada item do loop
    swathpltpars={
    'pointfl':walker_lake_declus.flname,
    'gridfl':kt3d_OK.flname,
    'griddef':walker_lake_declus.griddef,
    'outfl':'04 swathplots/swath_'+directions+'.ps',
    'dir':directions,
    'bins':'20',
    'xminmax':'0 -1',
    'yminmax':'0 -1 0',
    'title':'Swath plot '+directions
    }

    #adiciono os diferentes arquivos de parâmetro à lista vazia criada anteriormente
    callpars.append({'parstr':swathpltpar.format(**swathpltpars)})

    #finalemtne posso rodar em paralelo
gs.runparallel(swathplt, callpars, reportprogress=True)
# Out:
# Creating parallel processes
# VBox(children=(HTML(value=''), IntProgress(value=0, max=2)))
# Pool assembled, asynchronously processing
# Asynchronous execution finished.
